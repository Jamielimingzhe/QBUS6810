# %% [markdown]
# # <font color = '#e64626'><center>QBUS6810 Group Assignment</center></font>
# ### <center>Group 18: 490347812,470424164 , , , , </center>

# %% [markdown]
# # Table of Contents
#
# 1. [Data Processing](#data_processing)
# 2. [Exploratory Data Analysis](#eda)
# 3. [Feature Engineering](#feature_engineering)
# 4. [Methodology](#methodology)
# <br> 4.1 [Model 1: *model name*](#model_1)
# <br> 4.2 [Model 2: *model name*](#model_2)
# <br> 4.3 [Model 3: *model name*](#model_3)
# <br> 4.4 [Model 4: *model name*](#model_4)
# <br> 4.5 [Model 5: *model name*](#model_5)

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# import geopandas as gpd


from tqdm import tqdm
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from sklearn.model_selection import train_test_split,cross_val_predict,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression,RidgeCV, Ridge,LassoCV, Lasso,ElasticNetCV, ElasticNet
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor,StackingRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

from xgboost import XGBRegressor

# import statsmodels.api as sm
# import nltk
# import ast
# from nltk.tokenize import word_tokenize as wt

# %%
import sys
# !{sys.executable} -m pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\hezes\anaconda3\lib\site-packages (1.7.0)
# Requirement already satisfied: numpy in c:\users\hezes\anaconda3\lib\site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in c:\users\hezes\anaconda3\lib\site-packages (from xgboost) (1.9.1)

# %%
rc = {"xtick.labelsize": 12, "ytick.labelsize": 12, "axes.labelsize": 15, 
      "axes.titlesize": 15, "legend.fontsize": 12}
sns.set_context("notebook", rc=rc)

# %% [markdown]
# ## <font color = '#e64626'><a id='data_processing'>1. Data Processing</a></font>

# %%
train_4000 = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

train = pd.concat([train_4000,test],axis=0).reset_index(drop=True)

y = train['price'][:4000]
y_train_log = np.log(y)

# %%
train["host_response_time"] = train["host_response_time"].fillna('Others')
host_dummies = pd.get_dummies(train[["host_response_time","host_is_superhost","host_identity_verified","instant_bookable"]],drop_first=True)

train["host_response_rate"] = train["host_response_rate"].str.rstrip('%').astype('float') / 100.0
train["host_acceptance_rate"] = train["host_acceptance_rate"].str.rstrip('%').astype('float') / 100.0

train["host_response_rate"] = train["host_response_rate"].fillna(0)
train["host_acceptance_rate"] = train["host_acceptance_rate"].fillna(0)

# %%
train["host_verifications_clean"] = train['host_verifications'].astype('object')
for i in range(len(train["host_verifications"])):
    if train.loc[i,"host_verifications"] == "[]":
        train.at[i,"host_verifications_clean"] = []
    else:
        train.at[i,"host_verifications_clean"] = train.loc[i,"host_verifications"][2:-2].split("', '")
    
train['host_verifications_counts'] = [len(i) for i in train["host_verifications_clean"]]

# %%
train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# Out:
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/10/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/11/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/12/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/11/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/10/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/12/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '23/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '26/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '26/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/10/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '23/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/10/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '26/10/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/12/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/10/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/11/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '23/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '23/12/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/12/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/12/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/10/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '23/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/11/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/12/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '26/11/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/11/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/10/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/10/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/11/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/12/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/11/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '20/11/2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '26/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/10/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '17/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/11/2009' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/10/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '26/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '31/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/12/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/10/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/12/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '21/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '22/11/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/10/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '25/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/12/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/11/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '14/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2020' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/12/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/12/2013' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '28/10/2014' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '27/12/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '19/11/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '18/10/2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '23/11/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '30/10/2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '24/11/2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '16/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '29/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '13/10/2019' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/10/2021' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')
# C:\Users\hezes\AppData\Local\Temp\ipykernel_2820\2452887713.py:1: UserWarning: Parsing '15/12/2017' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   train['Host Days'] = (pd.to_datetime('2022-11-01') - pd.to_datetime(train['host_since']))/np.timedelta64(1, 'D')

# %%
p_type =train['property_type']
property_type_dummy = np.select(
    condlist=[
        p_type.str.contains('Private', case=False),
        p_type.str.contains('entire', case=False),
        ],
    choicelist=['Private', 'entire'],
    default='others'
)
property_type_dummy=pd.get_dummies(property_type_dummy)

# %%
type_dummies = pd.get_dummies(train[['property_type','room_type']],drop_first=True)

# %%
review_scores = train[['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']]

# %%
review_numbers = np.log(train[['number_of_reviews','reviews_per_month']])

# %%
host_numbers = pd.concat([train[['host_verifications_counts','host_response_rate',
                                 'host_acceptance_rate','Host Days','maximum_nights','minimum_nights']],
                          np.log(train['host_listings_count'])],axis=1)

# %%
train['amenities_clean'] = np.nan
train['amenities_clean'] = train['amenities_clean'].astype('object')

for i in tqdm(range(len(train['amenities']))):
    train.at[i,'amenities_clean'] = train.loc[i,'amenities'][2:-2].split('", "')
    
for i in tqdm(range(len(train['amenities_clean']))):
    for j in range(len(train.loc[i,'amenities_clean'])):
        if 'Fast wifi \\u2013' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Fast Wifi'
        if 'Wifi \\u2013' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Wifi'
        if 'HDTV' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'HD Television'
        if 'TV' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'TV'
        if 'body soap' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Body soap'
        if 'shampoo' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Shampoo'
        if 'refrigerator' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Refrigerator'
        if 'fridge' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Refrigerator'
        if 'conditioner' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Conditioner'
        if 'stove' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Stove'
        if 'oven' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Oven'
        if 'sound system' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Sound system'
        if 'Sound system' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Sound system'
        if 'Clothing storage' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Clothing storage'
        if 'Children\\u2019s books and toys' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Children\\u2019s books and toys'
        if 'Shared hot tub' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Hot tub'
        if 'Private hot tub' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private hot tub'
        if 'Shared pool' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Pool'
        if 'Shared indoor pool' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Pool'
        if 'Shared outdoor pool' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Pool'
        if 'Private pool' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private pool'
        if 'Private indoor pool' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private pool'
        if 'Private outdoor pool' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private pool'
        if 'Free washer' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Washer'
        if 'Paid washer' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Paid Washer'
        if 'Washer' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Washer'
        if 'Dryer' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Dryer'
        if 'Free dryer' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Dryer'
        if 'Paid dryer' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Paid Dryer'
        if 'on premises' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Parking on premises'
        if 'off premises' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Parking off premises'
        if 'Free street parking' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Parking off premises'
        if 'conditioning' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Air conditioning'
        if 'Game console' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Game console'
        if 'Gym' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Gym'
        if 'gym' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Gym'
        if 'coffee' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Coffee maker'
        if 'sauna' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Sauna'
        if 'high chair' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'High chair'
        if 'High chair' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'High chair'
        if 'crib' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Crib'
        if 'Crib' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Crib'
        if 'Fenced garden or backyard' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private garden or backyard'
        if 'Private fenced garden or backyard' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private garden or backyard'
        if 'Shared fenced garden or backyard' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Shared garden or backyard'
        if 'Private fenced garden or backyard' in train.loc[i,'amenities_clean'][j]:
            train.loc[i,'amenities_clean'][j] = 'Private garden or backyard'
        
amen_list = train['amenities_clean'].to_list()
vectorizer = CountVectorizer(analyzer=lambda x: x)
bow = vectorizer.fit_transform(amen_list)
bow_df = pd.DataFrame(bow.todense(), columns = vectorizer.get_feature_names_out())
# Out:
# 100%|██████████| 6000/6000 [00:00<00:00, 29741.67it/s]
# 100%|██████████| 6000/6000 [01:56<00:00, 51.41it/s]

# %%
train.loc[train['description'].isna(),'description'] = ''
train.loc[train['neighborhood_overview'].isna(),'neighborhood_overview'] = ''

# %%
corpus_des = [i for i in train['description']]
count_vectorizer = CountVectorizer(binary=True)
count_vectorizer.fit(corpus_des)
features = count_vectorizer.transform(corpus_des)

# %%
beach_index = count_vectorizer.get_feature_names_out().tolist().index('beach')
beach = np.array(features[:, beach_index].todense()).reshape(-1)
beach = pd.DataFrame(beach, columns=['beach_dummy'])

apartment_index = count_vectorizer.get_feature_names_out().tolist().index('city')
apartment = np.array(features[:, apartment_index].todense()).reshape(-1)
apartment = pd.DataFrame(apartment, columns=['city_dummy'])

walk_index = count_vectorizer.get_feature_names_out().tolist().index('bondi')
walk = np.array(features[:, walk_index].todense()).reshape(-1)
walk = pd.DataFrame(walk, columns=['walk_dummy'])

# %% [markdown]
# ## <font color = '#e64626'><a id='eda'>2. Exploratory Data Analysis</a></font>
#
# The example provided here is to show you how to save figures of an appropriate resolution by using <tt>dpi</tt>. The <tt>bbox_inches='tight'</tt> is used to ensure that when your figure is saved, there are no cropping issues. In the example, the figure is saved as a <tt>.png</tt>, but you may also want to save your figures as a <tt>.pdf</tt>.
#
# When you produce figures, make sure that all axes labels are readable. This notebook has been setup so that in general, the fontsizes are readable. These are defined in cell [2].
#
# You can change the dimensions of the figure by changing the `figsize`.

# %%
# Both Rate Seems to have no relationship with price, they are dropped
# plt.scatter(train["host_response_rate"],y_train_log)
# plt.scatter(train["host_acceptance_rate"],y_train_log)
# plt.scatter(train["host_listings_count"],y_train_log)
# plt.scatter(train['Host Days'][:4000],y_train_log)

# %%
plt.scatter(train["review_scores_value"][:4000],y_train_log)
plt.xlim(0,5)
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.hist(y, bins=100);
plt.xlabel('Price (AUD)')
plt.ylabel('Number of listings')
plt.savefig('hist_of_response.png', dpi=300, bbox_inches='tight')

# %%
train[['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']].corr()
# Out:
#                              review_scores_rating  review_scores_accuracy  \
# review_scores_rating                     1.000000                0.827904
# review_scores_accuracy                   0.827904                1.000000
# review_scores_cleanliness                0.796170                0.736365
# review_scores_checkin                    0.640491                0.642372
# review_scores_communication              0.711507                0.720729
# review_scores_location                   0.527271                0.529370
# review_scores_value                      0.799163                0.753475
#
#                              review_scores_cleanliness  review_scores_checkin  \
# review_scores_rating                          0.796170               0.640491
# review_scores_accuracy                        0.736365               0.642372
# review_scores_cleanliness                     1.000000               0.523055
# review_scores_checkin                         0.523055               1.000000
# review_scores_communication                   0.605266               0.733469
# review_scores_location                        0.435237               0.448455
# review_scores_value                           0.712360               0.589374
#
#                              review_scores_communication  \
# review_scores_rating                            0.711507
# review_scores_accuracy                          0.720729
# review_scores_cleanliness                       0.605266
# review_scores_checkin                           0.733469
# review_scores_communication                     1.000000
# review_scores_location                          0.502649
# review_scores_value                             0.664967
#
#                              review_scores_location  review_scores_value
# review_scores_rating                       0.527271             0.799163
# review_scores_accuracy                     0.529370             0.753475
# review_scores_cleanliness                  0.435237             0.712360
# review_scores_checkin                      0.448455             0.589374
# review_scores_communication                0.502649             0.664967
# review_scores_location                     1.000000             0.525794
# review_scores_value                        0.525794             1.000000

# %%
sns.heatmap(train[['review_scores_rating','review_scores_accuracy','review_scores_cleanliness','review_scores_checkin','review_scores_communication','review_scores_location','review_scores_value']].corr())
plt.show()

# %% [markdown]
# ## <font color = '#e64626'><a id='feature_engineering'>3. Feature Engineering</a></font>

# %%
# Using accommodates to predict missing bedrooms and beds
accomm_data_temp = train[['accommodates','bedrooms','beds']].dropna()
linear_reg = LinearRegression()

linear_reg.fit(np.array(accomm_data_temp['accommodates']).reshape(-1, 1), accomm_data_temp['bedrooms'])
train.loc[train['bedrooms'].isna(),'bedrooms'] = linear_reg.predict(np.array(train.loc[train['bedrooms'].isna(),'accommodates']).reshape(-1, 1)).round(0).astype('int')

linear_reg.fit(np.array(accomm_data_temp['accommodates']).reshape(-1, 1), accomm_data_temp['beds'])
train.loc[train['beds'].isna(),'beds'] = linear_reg.predict(np.array(train.loc[train['beds'].isna(),'accommodates']).reshape(-1, 1)).round(0).astype('int')

# %%
acc_room_bed = np.log(train[['accommodates','bedrooms','beds']])

# %% [markdown]
# ### Mapping Coordinates to Statistical Area 2 for more precision than neibourbood_cleased

# %%
# sydney = gpd.read_file('SA2_sydney/sydney_SA2.shp')
# sydney['region'] = sydney['geometry']
# geo_train = gpd.GeoDataFrame(train, geometry=gpd.points_from_xy(train.longitude, train.latitude))
# sydney.crs = "EPSG:7844"
# geo_train.crs = "EPSG:7844"
# geo_train_join = gpd.tools.sjoin(geo_train, sydney[['SA2_NAME21','geometry','region']], predicate="within", how='left')

# geo_nan = geo_train_join[geo_train_join['SA2_NAME21'].isna()][['latitude','longitude']]
# geo_nan = gpd.GeoDataFrame(geo_nan, geometry=gpd.points_from_xy(geo_nan.longitude, geo_nan.latitude))
# geo_nan.crs = "EPSG:7844"

# %%
# for i in geo_nan.index:
#     geo_train_join.loc[i,'SA2_NAME21'] = sydney.loc[sydney.distance(geo_nan.loc[i,'geometry']).sort_values().index[0],'SA2_NAME21']

# %%
# location = pd.get_dummies(geo_train_join['SA2_NAME21'])
location = pd.get_dummies(train['neighbourhood_cleansed'])
long_lat = train[['longitude','latitude']]

# %%
# geo_plot_df = pd.DataFrame(geo_train_join[:4000].groupby('SA2_NAME21').mean()['price'])
# geo_plot_df['median'] = geo_train_join[:4000].groupby('SA2_NAME21').median()['price']

# %%
# sydney_plot = sydney.set_index('SA2_NAME21')
# geo_plot = pd.concat([sydney_plot,np.log(geo_plot_df)],axis=1)

# %%
# geo_plot.plot(column='price',figsize=(20,10),legend=True,cmap='plasma',missing_kwds= dict(color = "lightgrey"))
# plt.xlim(150.5,151.35)
# plt.ylim(-34.2,-33)

# # plt.xlim(150.88,151.35)
# # plt.ylim(-34.1,-33.7)
# plt.show()

# %% [markdown]
# ## <font color = '#e64626'><a id='methodology'>4. Methodology</a></font>

# %% [markdown]
# ### <font color = '#e64626'><a id='model_1'>4.1. Model 1: OLS Lasso</a></font>

# %%
model1_features_all = pd.concat([beach,apartment,walk,host_dummies,host_numbers,acc_room_bed,
                             review_scores,review_numbers,long_lat,location,type_dummies,bow_df],axis=1)

scaler = StandardScaler()
scaler.fit(model1_features_all)
model1_features_all_scaled = scaler.transform(model1_features_all)

X_scaled = model1_features_all_scaled[:4000]
X_train_all = model1_features_all_scaled[:4000]

# %%
X_train_scaled, X_test_scaled, y_train_scaled, y_test = train_test_split(X_scaled, y_train_log, test_size = 0.2)
X_train, X_test, y_train, y_test = train_test_split(model1_features_all_scaled[:4000], y_train_log, test_size = 0.2)
ols = LinearRegression()
ols.fit(X_train, y_train);

lasso = LassoCV(cv=5)
lasso.fit(X_train_scaled, y_train_scaled)
best_lasso = Lasso(alpha=lasso.alpha_);
best_lasso.fit(X_train_scaled, y_train_scaled)
# Out:
# Lasso(alpha=0.0032396616813853175)

# %%
predictors = list(model1_features_all.columns.values)

n_coefs = 15
model = [ols, lasso]
model_name = ['OLS', 'Lasso']
plt.figure(figsize = (10, 10))

for i in range(len(model)):
    betas = model[i].coef_

    indicies = np.argsort(np.abs(betas))[-n_coefs:]
    top_predictors = np.array(predictors)[indicies]
    top_betas = betas[indicies]

    plt.subplot(2, 2, i+1)
    plt.barh(top_predictors, top_betas, alpha=0.5, edgecolor='black')
    sns.despine()
    plt.xlabel('Beta coefficient')
    plt.title(model_name[i]);
plt.suptitle('Figure 5. Top {} Beta Coefficients'.format(n_coefs), fontsize = 16)
plt.tight_layout()

# %%
model = [ols, lasso]
model_name = ['OLS', 'Lasso']
p = len(predictors)

plt.figure(figsize = (12, 10))
for i in range(len(model)):
    plt.subplot(len(model), 1, i+1)
    plt.bar(np.arange(p), model[i].coef_, width=1, alpha=0.5, edgecolor = 'black')
    plt.xticks([])
    plt.xlim([-1.5, p+0.5])
    plt.ylim([-0.1, 0.2])
    plt.ylabel(model_name[i] + '\nBeta Coefficient')
plt.xticks([0, 50, 100, 150])
plt.xlabel('Predictor Number')
plt.suptitle('Figure 6. Comparison of all Beta Coefficients', fontsize=16);

# %%
results = pd.DataFrame(columns=['RMSE', 'R2'])

ols = LinearRegression()
y_pred = cross_val_predict(ols, X_train_scaled, y_train_scaled, cv=5)

# OLS sometimes makes crazy predictions so we clip them to something sensible
y_pred = np.clip(y_pred, y_train.min(), y_train_scaled.max())

rmse = mean_squared_error(np.exp(y_train), np.exp(y_pred), squared=False)
r2 = r2_score(np.exp(y_train_scaled), np.exp(y_pred))

results.loc['OLS'] = rmse, r2

y_pred = cross_val_predict(best_lasso, X_train_scaled, y_train_scaled, cv=5)

rmse = mean_squared_error(np.exp(y_train_scaled), np.exp(y_pred), squared=False)
r2 = r2_score(np.exp(y_train_scaled), np.exp(y_pred))

results.loc['Lasso'] = rmse, r2

# %%
results.round(2)
# Out:
#          RMSE    R2
# OLS    304.88  0.61
# Lasso  244.74 -0.09

# %% [markdown]
# Now we need to generate the submission file.

# %%
# best_lasso.fit(X_scaled,y_train_log)

# id_col = np.arange(2000).reshape(-1, 1)
# y_pred = np.exp(best_lasso.predict(model1_features_all_scaled[4000:]).reshape(-1, 1))

# data = np.hstack((id_col, y_pred))

# m1_submission = pd.DataFrame(data, columns=['id', 'price'])
# m1_submission['id'] = m1_submission['id'].astype('int')

# m1_submission.to_csv('model1_Lasso_scaled_submission.csv', index=False)

# %% [markdown]
# ### <font color = '#e64626'><a id='model_2'>4.2. Model 2: *model name*</a></font>

# %%
X_train, X_test, y_train, y_test = train_test_split(model1_features_all_scaled[:4000], y_train_log, test_size = 0.2)

# %%
tree = DecisionTreeRegressor(min_samples_leaf=5, random_state=1)
path = tree.cost_complexity_pruning_path(X_train, y_train)

model = DecisionTreeRegressor(min_samples_leaf=5, random_state=1)

tuning_parameters = {'ccp_alpha': path.ccp_alphas,}
tree_cv = GridSearchCV(model, tuning_parameters, cv=5, return_train_score=False)
tree_cv.fit(X_train, y_train)

tree = tree_cv.best_estimator_
tree_cv.best_params_
# Out:
# {'ccp_alpha': 0.001095321270371338}

# %%
p = 5

importance = 100*(tree.feature_importances_/np.max(tree.feature_importances_))
feature_importance = pd.Series(importance, index=predictors).sort_values(ascending=True)
plt.figure(figsize=(27, 10))
plt.barh(np.arange(p), feature_importance[-p:])
plt.yticks(np.arange(p), feature_importance[-p:].index, fontsize=17)
plt.xticks(fontsize = 20)
plt.xlabel('% of maximum importance', fontsize=20)
plt.title('Figure 2. Variable importance of top {} predictors'.format(p), fontsize=20);
# plt.savefig('top 5.pdf')

# %%
# y_pred = np.exp(xgb.predict(model1_features_all_scaled[4000:]).reshape(-1, 1))

# data = np.hstack((id_col, y_pred))
# m2_submission = pd.DataFrame(data, columns=['id', 'price'])
# m2_submission['id'] = m2_submission['id'].astype('int')

# m2_submission.to_csv('model2_XGBoost_submission.csv', index=False)

# %% [markdown]
# ### <font color = '#e64626'><a id='model_3'>4.2. Model 3: *Random Forrest*</a></font>

# %%
X_train, X_test, y_train, y_test = train_test_split(model1_features_all[:4000], y_train_log, test_size = 0.2)

# %%
model = RandomForestRegressor(random_state=1)

tuning_parameters = {
    'min_samples_leaf': [5],
    'max_features': [100,150],
    'n_estimators': [600,700,800]
}

rf_cv = GridSearchCV(model, tuning_parameters, cv=5, return_train_score=False, n_jobs=4)
rf_cv.fit(X_train,y_train)
rf = rf_cv.best_estimator_

rf_cv.best_params_
# Out:
# {'max_features': 100, 'min_samples_leaf': 5, 'n_estimators': 800}

# %%
rf.fit(X_train,y_train)
rf.score(X_test, y_test)
# Out:
# 0.744783297655424

# %%
# y_pred = np.exp(rf.predict(model1_features_all_scaled[4000:]).reshape(-1, 1))

# data = np.hstack((id_col, y_pred))
# m3_submission = pd.DataFrame(data, columns=['id', 'price'])
# m3_submission['id'] = m3_submission['id'].astype('int')

# m3_submission.to_csv('model3_Random_Forrest_submission2.csv', index=False)

# %% [markdown]
# ### <font color = '#e64626'><a id='model_4'>4.2. Model 4: *gb*</a></font>

# %%
gb = GradientBoostingRegressor(learning_rate=0.05, max_depth=2, n_estimators=2000, subsample=0.5)
gb.fit(X_train,y_train);

# %%
p = 10

importance = 100*(gb.feature_importances_/np.max(gb.feature_importances_))
feature_importance = pd.Series(importance, index=predictors).sort_values(ascending=True)

plt.barh(np.arange(p), feature_importance[-p:])
plt.yticks(np.arange(p), feature_importance[-p:].index)
plt.xlabel('% of maximum importance')
plt.title('Figure 2. Variable importance of top {} predictors'.format(p));

# %%
gb.score(X_train,y_train)
# Out:
# 0.9144936776397191

# %%
# y_pred = np.exp(gb.predict(model1_features_all_scaled[4000:]).reshape(-1, 1))

# data = np.hstack((id_col, y_pred))
# m4_submission = pd.DataFrame(data, columns=['id', 'price'])
# m4_submission['id'] = m4_submission['id'].astype('int')

# m4_submission.to_csv('model4_Gradient_Boost_submission.csv', index=False)

# %% [markdown]
# ### <font color = '#e64626'><a id='mode_5'>4.2. Model 5: *Model Stack*</a></font>

# %%
y_fit = lasso.predict(X_train_scaled)
resid = y_train - y_fit

# %%
gb_boost = GradientBoostingRegressor(learning_rate=0.015,
                                     max_depth=2,
                                     n_estimators=2000, subsample=0.5)
gb_boost.fit(X_train, resid);

# %%
rf_boost = RandomForestRegressor(n_estimators=1000, min_samples_leaf=1,
                                 max_features=150, random_state=1, n_jobs=4)
rf_boost.fit(X_train, resid);

# %%
regressor=XGBRegressor(eval_metric='rmse')
param_grid = {"max_depth":    [6,7,8],
              "n_estimators": [1300,1400,1500,],
              "learning_rate": [0.015,0.02],
             'min_child_weight':[0.5,0.75]}
search = GridSearchCV(regressor, param_grid, cv=5).fit(X_train, y_train)
xgb=XGBRegressor(learning_rate = search.best_params_["learning_rate"],
                           n_estimators  = search.best_params_["n_estimators"],
                           max_depth     = search.best_params_["max_depth"],
               sampling_method= 'gradient_based',subsample=0.1,tree_method='gpu_hist',
                 objective='reg:squarederror',booster='gbtree',reg_lambda=0,reg_alpha=0, n_jobs=4,
                 process_type='default')

# %%
xgbb=XGBRegressor(learning_rate = search.best_params_["learning_rate"],
                           n_estimators  = search.best_params_["n_estimators"],
                           max_depth     = search.best_params_["max_depth"],
               sampling_method= 'gradient_based',subsample=0.1,tree_method='gpu_hist',
                 objective='reg:squarederror',booster='gbtree',reg_lambda=0,reg_alpha=0, n_jobs=4,
                 process_type='default')

# %%
xgb.fit(X_train_all, y_train_log)
xgbb.fit(X_train_all, resid)

# %%
models = [('Lasso', best_lasso), ('Random Forest', rf_boost), ('Gradient Boost', gb_boost),('XGboost', xgb),('XGboost boost', xgbb)]

stack = StackingRegressor(models, final_estimator=LassoCV(positive=True,cv=5), cv=5, n_jobs=4)
stack.fit(X_train,y_train_log)

# %%
plt.barh(np.arange(len(models)), stack.final_estimator_.coef_)
plt.yticks(np.arange(len(models)), ['Lasso', 'Random Forest boost','Gradient Boost boost','XGboost','XGboost boost'])
plt.xlabel('Model coefficient')
plt.title('Figure 4. Model coefficients for our stacked model')

# %%
methods = {
#     'OLS': ols,
    'Lasso': best_lasso,
    'Model Stack': stack,
    'Random Forest Boost': rf_boost,
    'Gradient Boost Boost': gb_boost,
    'XGboost':xgb,
    'XGboost boost':xgbb
}

test = pd.DataFrame(columns=['RMSE', 'R2'])

for name, model in methods.items():
    if name in ['Lasso']:
        y_pred = model.predict(X_test_scaled)
    elif name in ['Random Forest Boost', 'Gradient Boost Boost',"'XGboost boost'"]:
        y_pred = lasso.predict(X_test_scaled) + model.predict(X_test)
    else:
        y_pred = model.predict(X_test)
        
    rmse = mean_squared_error(y_test, y_pred, squared=False)
    r2 = r2_score(y_test, y_pred)
    test.loc[name] = rmse, r2

test.round(4)

# %%
best_lasso.fit(X_scaled, y_train_log)
tree_cv.fit(X_train_all, y_train_log)
rf.fit(X_train_all, y_train_log)
gb.fit(X_train_all, y_train_log);
rf_boost.fit(X_train_all, resid);
gb_boost.fit(X_train_all, resid);
xgb.fit(X_train_all, y_train_log)
xgbb.fit(X_train_all, resid)

# %%
models = [('Lasso', best_lasso), ('Random Forest', rf_boost), ('Gradient Boost', gb_boost),('XGboost', xgb),('XGboost boost', xgbb)]

stack = StackingRegressor(models, final_estimator=LassoCV(positive=True,cv=5), cv=5, n_jobs=4)
stack.fit(X_train_all,y_train_log)

# %%
X_train1 = model1_features_all_scaled[:4000]
X_test1 = model1_features_all_scaled[4000:6000]
y_train = y

stack = StackingRegressor(models, final_estimator=LassoCV(positive=True,cv=5), cv=5, n_jobs=4)
stack.fit(X_train, y_train);

y_pred = stack.predict(X_test1)
y_pred

y_fit_ms = stack.predict(X_train1)
resid_ms = y_train - y_fit_ms

prediction = np.exp(y_pred)*np.mean(np.exp(resid_ms))
prediction

# %%
submission = pd.DataFrame(prediction,columns=['price'])
submission.index.names = ['id']
submission=submission['price']
submission = pd.DataFrame(submission).to_csv('Gradiant boost_submission_zeshen.csv')

# m5_submission.to_csv('model5_Stack_Lasso_RF_GB_submission.csv', index=False)
